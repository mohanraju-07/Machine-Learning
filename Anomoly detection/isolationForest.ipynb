# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df=df.drop('color',axis=1)
df.head()
# Out:
#             x           y
# 0  516.012706  393.014514
# 1  436.211762  408.656585
# 2  512.052601  372.022014
# 3  489.140464  401.807159
# 4  446.207986  338.516682

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.ensemble import IsolationForest 

plt.scatter(df['x'],df['y'])
plt.show()

# %%
isof=IsolationForest(contamination=0.2)
pred=isof.fit_predict(df)

out=df[pred<0]

z=df.values
plt.scatter(df['x'],df['y'])
plt.scatter(out['x'],out['y'],edgecolors='r')
plt.show()
